# %% [markdown]
# # Example: Scanning Python packages using the API

# %%
from codeaudit.api_interfaces import filescan

# %%
packagename = "linkaudit" #This is a great package on PyPI.org to check for broken links in markdown files.

# %%
result = filescan(packagename)  # linkaudit is a package that is present on PyPI.org

# %%
result
# Out:
# {'name': 'Python_Code_Audit',
#  'version': '1.6.2',
#  'generated_on': '2026-04-10 16:09',
#  'package_name': 'linkaudit',
#  'package_release': '0.9.8',
#  'statistics_overview': {'Number_Of_Files': 6,
#   'Number_Of_Lines': 523,
#   'AST_Nodes': 225,
#   'Core Modules': 6,
#   'External Modules': 3,
#   'Functions': 16,
#   'Classes': 0,
#   'Comment_Lines': 194,
#   'Median_Complexity': 9.3,
#   'Maximum_Complexity': 26},
#  'module_overview': {'core_modules': ['asyncio',
#    'os',
#    're',
#    'sys',
#    'urllib.error',
#    'urllib.request'],
#   'imported_modules': ['_version', 'fire', 'linkaudit']},
#  'file_security_info': {0: {'FileName': '__init__.py',
#    'FilePath': '/tmp/codeaudit_sviyoehh/linkaudit-0.9.8/src/linkaudit/__init__.py',
#    'Number_Of_Lines': 10,
#    'AST_Nodes': 2,
#    'Std-Modules': 0,
#    'External-Modules': 1,
#    'Functions': 0,
#    'Classes': 0,
#    'Comment_Lines': 8,
#    'Complexity_Score': 1,
#    'warnings': 0,
# ...
